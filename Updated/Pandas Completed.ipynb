# %% [markdown]
# # `Traditional way of reading structure dataset => hard way`
# ### `Method 1`

# %%
path = r"mobile_data.csv"

data = []
with open(path,mode="r") as file:
    for line in file.readlines():
        elements = line.split(",")
        elements[-1] = elements[-1].replace("\n","")
        data.append(elements)

# %%
import numpy as np

data = np.array(data[1:])
data = data.astype(float)

# %%
data.mean(axis=1)
# Out:
# array([ 184.6    ,  195.8925 ,  237.0885 ,  267.3225 ,  274.803  ,
#         267.8425 ,  258.89   ,  254.7525 ,  258.48   ,  287.91   ,
#         318.93   ,  287.87   ,  289.1175 ,  282.0225 ,  289.385  ,
#         304.925  ,  287.5625 ,  289.785  ,  290.5175 ,  302.195  ,
#         353.035  ,  324.995  ,  314.4625 ,  312.6025 ,  335.0675 ,
#         421.72   ,  364.205  ,  356.5275 ,  347.8775 ,  383.27   ,
#         356.48   ,  365.4    ,  381.4875 ,  410.915  ,  410.79   ,
#         404.7    ,  356.3675 ,  382.59   ,  347.5425 ,  386.805  ,
#         396.04   ,  432.6625 ,  439.11   ,  409.0225 ,  438.555  ,
#         460.5025 ,  426.04   ,  445.5675 ,  482.8525 ,  491.735  ,
#         482.94   ,  477.3525 ,  502.615  ,  485.5375 ,  489.545  ,
#         522.4    ,  521.6025 ,  489.48   ,  528.3525 ,  511.8975 ,
#         559.8975 ,  515.2125 ,  543.54   ,  590.685  ,  550.2725 ,
#         577.2    ,  608.6525 ,  586.8225 ,  602.02   ,  662.19   ,
# ...

# %% [markdown]
# ### `Method 2`

# %%
data = np.genfromtxt("mobile_data.csv",delimiter=",")
data
# Out:
# array([[     nan,      nan,      nan, ...,      nan,      nan,      nan],
#        [0.00e+00, 1.20e+01, 5.50e+01, ..., 2.00e+03, 1.25e+02, 1.00e+00],
#        [0.00e+00, 1.00e+00, 5.50e+01, ..., 2.00e+03, 1.65e+02, 1.00e+00],
#        ...,
#        [3.00e+00, 1.00e+01, 6.00e+00, ..., 2.75e+03, 1.00e+00, 1.00e+00],
#        [3.00e+00, 1.00e+01, 1.20e+01, ..., 1.81e+03, 7.00e+00, 1.00e+00],
#        [2.00e+00, 8.00e+00, 3.00e+00, ..., 3.00e+03, 2.00e+00, 0.00e+00]])

# %% [markdown]
# # `Pandas --------------------------------------------`
# - `Pandas is written on top of Numpy`
# - Why we need Pandas(Data Processing+visualization), Why not directly use excel
# - Excel: os dependent, hant handle multiple files at same time, support only 6500000 records, excel is not memory effiecient become slow.

# %%
import pandas as pd

# %%
data = pd.read_csv("mobile_data.csv")
data.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
data.columns # its going to give us list of column names available
# Out:
# Index(['sim_type', 'aperture', 'gpu_rank', 'weight', 'stand_by_time',
#        'processor_frequency', 'thickness', 'flash_type',
#        'front_camera_resolution', 'auto_focus', 'screen_size',
#        'frames_per_second', 'FM', 'no_of_reviews_in_gsmarena_in_week', 'os',
#        'phone_height', 'screen_protection', 'sim_size', 'price', 'talk_time',
#        'video_resolution', 'display_resolution', 'removable_battery',
#        'display_type', 'primary_camera_resolution', 'battery_type',
#        'ram_memory', 'internal_memory', 'brand_rank', 'no_of_cores',
#        'micro_sd_slot', 'screen_pixel_density', 'water_proof_rate',
#        'phone_width', 'expandable_memory', 'version', 'usb_type',
#        'battery_capacity', 'processor_rank', 'is_liked'],
#       dtype='object')

# %%
# Getting a dimension
data.shape # -> (109, 40) -> 109 rows ; 40 columns
# Out:
# (109, 40)

# %%
data.dtypes # to get the datatype of each columns
# Out:
# sim_type                               int64
# aperture                               int64
# gpu_rank                               int64
# weight                               float64
# stand_by_time                          int64
# processor_frequency                  float64
# thickness                            float64
# flash_type                             int64
# front_camera_resolution              float64
# auto_focus                             int64
# screen_size                          float64
# frames_per_second                      int64
# FM                                     int64
# no_of_reviews_in_gsmarena_in_week      int64
# os                                     int64
# phone_height                         float64
# screen_protection                      int64
# sim_size                               int64
# price                                  int64
# talk_time                              int64
# video_resolution                       int64
# ...

# %% [markdown]
# ### `Sometimes pandas may assign wrong datatypes`

# %%
# Bring sample of first 5 records
data.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %% [markdown]
# # `Extracting a sample records from Dataframe / Series`

# %%
# Bring sample of first 10 records
data.head(10)
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
# 5         0        14        55   179.0            280                  1.3
# 6         1         1        56   124.0            230                  1.3
# 7         0         8        41   154.0            182                  1.0
# 8         1         8        41   214.0            182                  1.0
# 9         0         1        55   155.0            435                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# ...

# %%
# Bring sample of last 6 records
data.tail()
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
#      thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 104        9.4           2                      2.0           2  ...
# 105        7.7           5                      5.0           3  ...
# 106        7.3           2                      5.0           3  ...
# 107        6.9           2                      1.2           3  ...
# 108        7.4           6                      8.0           3  ...
#
#      micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
# Bring sample of last 16 records
data.tail(16)
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 93          3        10        12   129.0            250                  1.4
# 94          3        10        12   129.0            250                  1.4
# 95          3        10        28   168.0            580                  2.2
# 96          3        12        16   149.0            410                  2.5
# 97          0         8         9   154.0            340                  2.0
# 98          3         2         8   132.0            362                  1.5
# 99          3        10        12   129.0            250                  1.4
# 100         0         5         3   152.0            242                  2.3
# 101         3        10         6   143.0            240                  1.8
# 102         0         7        43   171.0            330                  2.1
# 103         3         8         9   180.0            600                  2.0
# ...

# %%
# take random sampled row from a dataframe
data.sample()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 9         0         1        55   155.0            435                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 9       11.6           5                      2.0           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 9              4                     9                 6         72.4
#
#    expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 9                 32        5         3              3000             125
#
#    is_liked
# 9         1
#
# [1 rows x 40 columns]

# %%
# take random sampled row from a dataframe -> 10
data.sample(10)
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 10          0         1        55   169.0            514                  1.3
# 32          0         8        43   155.0            250                  1.4
# 54          0         1        44   154.5            560                  1.7
# 50          0         7        29   171.0            354                  1.6
# 108         2         8         3   158.0            400                  2.2
# 35          0         8        34   150.0            750                  1.7
# 80          1         8         3   129.0            598                  1.8
# 74          3        10        16   145.0            390                  1.9
# 60          2        10        16   175.0            840                  2.5
# 61          0         8        29   134.0            380                  1.7
#
#      thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# ...

# %% [markdown]
# # `Datatypes inside pandas`
# ### - Series
# ### - DataFrame
# ### - ~~Panel~~: we don't use it, multi-D dataframe

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data["sim_type"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # `Get Dimension of dataframe/ Series`

# %%
data.shape # (row count, column count)
# Out:
# (109, 40)

# %%
data.size
# Out:
# 4360

# %%
109*40
# Out:
# 4360

# %% [markdown]
# # `Get values alone in pandas and put inside numpy array`

# %%
data.columns # -> extract only columns
# Out:
# Index(['sim_type', 'aperture', 'gpu_rank', 'weight', 'stand_by_time',
#        'processor_frequency', 'thickness', 'flash_type',
#        'front_camera_resolution', 'auto_focus', 'screen_size',
#        'frames_per_second', 'FM', 'no_of_reviews_in_gsmarena_in_week', 'os',
#        'phone_height', 'screen_protection', 'sim_size', 'price', 'talk_time',
#        'video_resolution', 'display_resolution', 'removable_battery',
#        'display_type', 'primary_camera_resolution', 'battery_type',
#        'ram_memory', 'internal_memory', 'brand_rank', 'no_of_cores',
#        'micro_sd_slot', 'screen_pixel_density', 'water_proof_rate',
#        'phone_width', 'expandable_memory', 'version', 'usb_type',
#        'battery_capacity', 'processor_rank', 'is_liked'],
#       dtype='object')

# %%
data.values # -> extract only value not column names
# Out:
# array([[0.00e+00, 1.20e+01, 5.50e+01, ..., 2.00e+03, 1.25e+02, 1.00e+00],
#        [0.00e+00, 1.00e+00, 5.50e+01, ..., 2.00e+03, 1.65e+02, 1.00e+00],
#        [0.00e+00, 9.00e+00, 5.50e+01, ..., 2.50e+03, 1.64e+02, 0.00e+00],
#        ...,
#        [3.00e+00, 1.00e+01, 6.00e+00, ..., 2.75e+03, 1.00e+00, 1.00e+00],
#        [3.00e+00, 1.00e+01, 1.20e+01, ..., 1.81e+03, 7.00e+00, 1.00e+00],
#        [2.00e+00, 8.00e+00, 3.00e+00, ..., 3.00e+03, 2.00e+00, 0.00e+00]])

# %% [markdown]
# # `Dataframe information`

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   sim_type                           109 non-null    int64
#  1   aperture                           109 non-null    int64
#  2   gpu_rank                           109 non-null    int64
#  3   weight                             109 non-null    float64
#  4   stand_by_time                      109 non-null    int64
#  5   processor_frequency                109 non-null    float64
#  6   thickness                          109 non-null    float64
#  7   flash_type                         109 non-null    int64
#  8   front_camera_resolution            109 non-null    float64
#  9   auto_focus                         109 non-null    int64
#  10  screen_size                        109 non-null    float64
# ...

# %% [markdown]
# # `Accessing the data from pandas Dataframe`

# %%
data.columns
# Out:
# Index(['sim_type', 'aperture', 'gpu_rank', 'weight', 'stand_by_time',
#        'processor_frequency', 'thickness', 'flash_type',
#        'front_camera_resolution', 'auto_focus', 'screen_size',
#        'frames_per_second', 'FM', 'no_of_reviews_in_gsmarena_in_week', 'os',
#        'phone_height', 'screen_protection', 'sim_size', 'price', 'talk_time',
#        'video_resolution', 'display_resolution', 'removable_battery',
#        'display_type', 'primary_camera_resolution', 'battery_type',
#        'ram_memory', 'internal_memory', 'brand_rank', 'no_of_cores',
#        'micro_sd_slot', 'screen_pixel_density', 'water_proof_rate',
#        'phone_width', 'expandable_memory', 'version', 'usb_type',
#        'battery_capacity', 'processor_rank', 'is_liked'],
#       dtype='object')

# %%
data["aperture"]
# Out:
# 0      12
# 1       1
# 2       9
# 3       8
# 4       1
#        ..
# 104    10
# 105     5
# 106    10
# 107    10
# 108     8
# Name: aperture, Length: 109, dtype: int64

# %%
columns_needed = ['sim_type', 'aperture']
data[columns_needed]
# Out:
#      sim_type  aperture
# 0           0        12
# 1           0         1
# 2           0         9
# 3           0         8
# 4           1         1
# ..        ...       ...
# 104         3        10
# 105         0         5
# 106         3        10
# 107         3        10
# 108         2         8
#
# [109 rows x 2 columns]

# %%
data[['sim_type', 'aperture']] # list of columns namesdata[['sim_type', 'aperture']]
# Out:
#      sim_type  aperture
# 0           0        12
# 1           0         1
# 2           0         9
# 3           0         8
# 4           1         1
# ..        ...       ...
# 104         3        10
# 105         0         5
# 106         3        10
# 107         3        10
# 108         2         8
#
# [109 rows x 2 columns]

# %%
type(data[['sim_type']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['sim_type'])
# Out:
# pandas.core.series.Series

# %%
data[['sim_type', 'aperture','front_camera_resolution']]
# Out:
#      sim_type  aperture  front_camera_resolution
# 0           0        12                     2.00
# 1           0         1                     0.30
# 2           0         9                     2.00
# 3           0         8                     2.00
# 4           1         1                     1.92
# ..        ...       ...                      ...
# 104         3        10                     2.00
# 105         0         5                     5.00
# 106         3        10                     5.00
# 107         3        10                     1.20
# 108         2         8                     8.00
#
# [109 rows x 3 columns]

# %% [markdown]
# # `Indexing, Selecting and Slicing Data in Pandas`
#
# ### Pandas now supports two types of Multi-axes indexing:
#
# **.loc()** index based selection
# - Pandas provide various methods to have purely **label based indexing**. When slicing, the start bound is also included. Integers are valid labels, but they refer to the label and not the position.
#
# **.iloc()** location based selection
# - Pandas provide various methods in order to get purely **integer based indexing**. Like python and numpy, these are 0-based indexing.
#
# ### 1:08:45

# %% [markdown]
# ## `loc()`

# %%
data["sim_type"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 104    3
# 105    0
# 106    3
# 107    3
# 108    2
# Name: sim_type, Length: 109, dtype: int64

# %%
data.loc[:,"sim_type"] # data.loc[row, col]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 104    3
# 105    0
# 106    3
# 107    3
# 108    2
# Name: sim_type, Length: 109, dtype: int64

# %%
data.loc[0:5,"sim_type"]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# 5    0
# Name: sim_type, dtype: int64

# %%
data.loc[:,['sim_type', 'aperture','front_camera_resolution']]
# Out:
#      sim_type  aperture  front_camera_resolution
# 0           0        12                     2.00
# 1           0         1                     0.30
# 2           0         9                     2.00
# 3           0         8                     2.00
# 4           1         1                     1.92
# ..        ...       ...                      ...
# 104         3        10                     2.00
# 105         0         5                     5.00
# 106         3        10                     5.00
# 107         3        10                     1.20
# 108         2         8                     8.00
#
# [109 rows x 3 columns]

# %%
data.loc[100:,['sim_type', 'aperture','front_camera_resolution']]
# Out:
#      sim_type  aperture  front_camera_resolution
# 100         0         5                      5.0
# 101         3        10                      5.0
# 102         0         7                      5.0
# 103         3         8                      5.0
# 104         3        10                      2.0
# 105         0         5                      5.0
# 106         3        10                      5.0
# 107         3        10                      1.2
# 108         2         8                      8.0

# %%
data.loc[100,['sim_type', 'aperture','front_camera_resolution']]
# Out:
# sim_type                   0.0
# aperture                   5.0
# front_camera_resolution    5.0
# Name: 100, dtype: float64

# %% [markdown]
# ## `iloc()`

# %%
data.iloc[:,:]
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0            250                  1.3
# 1           0         1        55   132.0            300                  1.3
# 2           0         9        55   142.0            329                  1.5
# 3           0         8        55   152.0            385                  1.3
# 4           1         1        55   234.0            385                  1.3
# ..        ...       ...       ...     ...            ...                  ...
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
# ...

# %% [markdown]
# ### `wrong way to give`

# %%
data.loc[:,['sim_type', 'aperture','front_camera_resolution']]
# Out:
#      sim_type  aperture  front_camera_resolution
# 0           0        12                     2.00
# 1           0         1                     0.30
# 2           0         9                     2.00
# 3           0         8                     2.00
# 4           1         1                     1.92
# ..        ...       ...                      ...
# 104         3        10                     2.00
# 105         0         5                     5.00
# 106         3        10                     5.00
# 107         3        10                     1.20
# 108         2         8                     8.00
#
# [109 rows x 3 columns]

# %%
data.iloc[:,0:3]
# Out:
#      sim_type  aperture  gpu_rank
# 0           0        12        55
# 1           0         1        55
# 2           0         9        55
# 3           0         8        55
# 4           1         1        55
# ..        ...       ...       ...
# 104         3        10        14
# 105         0         5         3
# 106         3        10         6
# 107         3        10        12
# 108         2         8         3
#
# [109 rows x 3 columns]

# %%
data.iloc[:,4:]
# Out:
#      stand_by_time  processor_frequency  thickness  flash_type  \
# 0              250                  1.3       10.5           5
# 1              300                  1.3       10.6           5
# 2              329                  1.5        8.5           5
# 3              385                  1.3        8.0           5
# 4              385                  1.3        7.9           5
# ..             ...                  ...        ...         ...
# 104            540                  1.8        9.4           2
# 105            400                  2.3        7.7           5
# 106            384                  1.8        7.3           2
# 107            250                  1.4        6.9           2
# 108            400                  2.2        7.4           6
#
#      front_camera_resolution  auto_focus  screen_size  frames_per_second  FM  \
# 0                       2.00           0          4.5                 15   3
# ...

# %% [markdown]
# ## `To get column index`

# %%
data.columns.get_loc("screen_size")
# Out:
# 10

# %%
data.iloc[:,10:]
# Out:
#      screen_size  frames_per_second  FM  no_of_reviews_in_gsmarena_in_week  \
# 0            4.5                 15   3                                  0
# 1            4.0                 30   2                                  6
# 2            5.0                 30   2                                 20
# 3            5.0                 15   3                                  0
# 4            5.0                 15   3                                  0
# ..           ...                ...  ..                                ...
# 104          5.4                 30   1                                  0
# 105          5.5                 30   4                                144
# 106          5.5                 30   4                                 81
# 107          4.7                 60   4                                 39
# 108          5.5                 30   1                                  0
#
# ...

# %% [markdown]
# ## `Condition & slicing in pandas`

# %%
data[data["processor_frequency"] >= 2.5]
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 58         3         6        16   149.0            280                  2.5
# 59         3         3        16   144.0            250                  2.5
# 60         2        10        16   175.0            840                  2.5
# 71         3         8        16   162.0            360                  2.5
# 85         3        10        11   176.0            200                  2.7
# 96         3        12        16   149.0            410                  2.5
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 58        8.9           5                      8.0           3  ...
# 59       10.0           2                     13.0           3  ...
# 60        8.9           3                      8.0           3  ...
# 71        8.9           2                      5.0           3  ...
# 85        8.5           5                      3.7           3  ...
# ...

# %%
data[(data["processor_frequency"] >= 2.5) & (data["stand_by_time"] >= 300)]
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 60         2        10        16   175.0            840                  2.5
# 71         3         8        16   162.0            360                  2.5
# 96         3        12        16   149.0            410                  2.5
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 60        8.9           3                      8.0           3  ...
# 71        8.9           2                      5.0           3  ...
# 96        8.9           3                      2.1           3  ...
#
#     micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 60              0                    16                 3         77.3
# 71              1                    16                 6         75.9
# 96              4                    28                 6         74.6
#
#     expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# ...

# %%
data[(data["processor_frequency"] >= 2.5) & (data["stand_by_time"] >= 300)][["sim_type","aperture"]] 
# -> chaining (not to use all the time; not a efficient way)
# Out:
#     sim_type  aperture
# 60         2        10
# 71         3         8
# 96         3        12

# %%
data.loc[(data["processor_frequency"] >= 2.5) & (data["stand_by_time"] >= 300), ["sim_type","aperture"]]
# Out:
#     sim_type  aperture
# 60         2        10
# 71         3         8
# 96         3        12

# %% [markdown]
# ### `will not work for bool condition`

# %%
data.iloc[data['processor_frequency'] > 2.3 , 4:5]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6632/2459673877.py in <module>
# ----> 1 data.iloc[data['processor_frequency'] > 2.3 , 4:5]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %% [markdown]
# # `Sample complex condition in pandas`

# %%
data[ (data['processor_frequency'] > 2.3) & (data["sim_type"] ==3) ]
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 58         3         6        16   149.0            280                  2.5
# 59         3         3        16   144.0            250                  2.5
# 71         3         8        16   162.0            360                  2.5
# 85         3        10        11   176.0            200                  2.7
# 96         3        12        16   149.0            410                  2.5
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 58        8.9           5                      8.0           3  ...
# 59       10.0           2                     13.0           3  ...
# 71        8.9           2                      5.0           3  ...
# 85        8.5           5                      3.7           3  ...
# 96        8.9           3                      2.1           3  ...
#
#     micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
data.loc[ (data['processor_frequency'] > 2.3) & (data["sim_type"] ==3), ["gpu_rank","weight","stand_by_time"] ]
# Out:
#     gpu_rank  weight  stand_by_time
# 58        16   149.0            280
# 59        16   144.0            250
# 71        16   162.0            360
# 85        11   176.0            200
# 96        16   149.0            410

# %% [markdown]
# # `Statistics in pandas`
# - mean
# - medain
# - mode
# - max
# - std
# - var
# - min
# - count
# - sum
# - idxmin
# - idxmax

# %%
data.describe() # only for numerical columns
# Out:
#          sim_type    aperture    gpu_rank      weight  stand_by_time  \
# count  109.000000  109.000000  109.000000  109.000000      109.00000
# mean     0.981651    7.733945   29.990826  154.358716      404.66055
# std      1.347025    3.201973   15.300385   22.394333      176.44206
# min      0.000000    0.000000    3.000000   97.000000      160.00000
# 25%      0.000000    8.000000   16.000000  140.000000      264.00000
# 50%      0.000000    8.000000   29.000000  152.000000      360.00000
# 75%      3.000000   10.000000   41.000000  169.000000      500.00000
# max      4.000000   14.000000   56.000000  234.000000     1093.00000
#
#        processor_frequency   thickness  flash_type  front_camera_resolution  \
# count           109.000000  109.000000  109.000000               109.000000
# mean              1.633394    8.330275    3.844037                 4.840550
# std               0.386773    1.173828    1.582159                 2.578122
# ...

# %%
data.mean() # by default axis = 0; col mean
# Out:
# sim_type                                 0.981651
# aperture                                 7.733945
# gpu_rank                                29.990826
# weight                                 154.358716
# stand_by_time                          404.660550
# processor_frequency                      1.633394
# thickness                                8.330275
# flash_type                               3.844037
# front_camera_resolution                  4.840550
# auto_focus                               2.954128
# screen_size                              5.211468
# frames_per_second                       30.550459
# FM                                       2.559633
# no_of_reviews_in_gsmarena_in_week      108.266055
# os                                       0.183486
# phone_height                           146.865138
# screen_protection                       14.623853
# sim_size                                 6.211009
# price                                19373.211009
# ...

# %%
data.mean(axis=1) # row mean
# Out:
# 0       184.6000
# 1       195.8925
# 2       237.0885
# 3       267.3225
# 4       274.8030
#          ...
# 104    1548.4700
# 105    1602.3500
# 106    1625.3675
# 107    1706.0075
# 108     854.8125
# Length: 109, dtype: float64

# %%
data["processor_rank"].mean()
# Out:
# 50.788990825688074

# %% [markdown]
# # `Axis in pandas`:
# ![](https://i.stack.imgur.com/OuyFd.png)

# %% [markdown]
# ## `idxmin to index of min value`
# - Return index of first occurrence of minimum over requested axis.

# %%
data[data["processor_frequency"]==1]
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 7          0         8        41   154.0            182                  1.0
# 8          1         8        41   214.0            182                  1.0
# 48         0         3        41   148.0            566                  1.0
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 7         8.1           5                      2.0           3  ...
# 8         8.2           5                      2.0           3  ...
# 48        9.3           5                      5.0           3  ...
#
#     micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 7               4                     9                 3         78.0
# 8               4                     9                 6         80.0
# 48              3                     9                 6         71.8
#
#     expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# ...

# %%
data["processor_frequency"].min()
# Out:
# 1.0

# %%
data["processor_frequency"].idxmin()
# Out:
# 7

# %%
data.loc[7,"processor_frequency"]
# Out:
# 1.0

# %% [markdown]
# ## `idxmax to index of max value`
# - - Return index of first occurrence of maximum over requested axis.

# %%
data[data["processor_frequency"]==2.7]
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 85         3        10        11   176.0            200                  2.7
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 85        8.5           5                      3.7           3  ...
#
#     micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 85              4                    24                 6         78.6
#
#     expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 85                128        4         3              3220               9
#
#     is_liked
# 85         1
#
# [1 rows x 40 columns]

# %%
data["processor_frequency"].max()
# Out:
# 2.7

# %%
data["processor_frequency"].idxmax()
# Out:
# 85

# %%
data.loc[85,"processor_frequency"]
# Out:
# 2.7

# %% [markdown]
# # `Topic to cover`
# - ~~Sort dataframe~~
# - ~~Create a new columns and calculation of columns~~
#     - ~~data type conversion~~
#     - ~~Replace a value using loc & condition~~
# - ~~Dropping a columns~~
# - ~~groupby and aggr~~
# - ~~Renaming~~
# - ~~set_index & reset_index~~
# - ~~multi indexing~~
# - ~~Pivot~~
# - ~~Stacking / unstacking~~
# - ~~Crosstab~~
# - ~~concat~~
# - ~~joins & merge~~
# - ~~iteration (For loop, apply, swifter(if possible))~~
# - ~~str operation~~
# - ~~handling and finding missing values~~
# - ~~plot using pandas~~

# %% [markdown]
# ## `Sort values`

# %%
data.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
data.sort_values("aperture") # will not change the memory
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 38         2         0        27   128.0            490                  1.7
# 54         0         1        44   154.5            560                  1.7
# 55         1         1        44   171.8           1093                  1.4
# 40         0         1        38   143.0            275                  1.3
# 28         0         1        44   160.0            617                  1.7
# ..       ...       ...       ...     ...            ...                  ...
# 96         3        12        16   149.0            410                  2.5
# 0          0        12        55   155.0            250                  1.3
# 63         0        13        29   189.0            600                  1.5
# 47         0        13        34   138.0            761                  1.7
# 5          0        14        55   179.0            280                  1.3
#
# ...

# %%
data # proof-> loak at the column aperture, its not in sorted order
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0            250                  1.3
# 1           0         1        55   132.0            300                  1.3
# 2           0         9        55   142.0            329                  1.5
# 3           0         8        55   152.0            385                  1.3
# 4           1         1        55   234.0            385                  1.3
# ..        ...       ...       ...     ...            ...                  ...
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
# ...

# %%
data = data.sort_values("aperture")  # sort and storing it back to the memory (reassigining is required)

# %%
data # sorted value
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 38         2         0        27   128.0            490                  1.7
# 54         0         1        44   154.5            560                  1.7
# 55         1         1        44   171.8           1093                  1.4
# 40         0         1        38   143.0            275                  1.3
# 28         0         1        44   160.0            617                  1.7
# ..       ...       ...       ...     ...            ...                  ...
# 96         3        12        16   149.0            410                  2.5
# 0          0        12        55   155.0            250                  1.3
# 63         0        13        29   189.0            600                  1.5
# 47         0        13        34   138.0            761                  1.7
# 5          0        14        55   179.0            280                  1.3
#
# ...

# %% [markdown]
# # `Sorting value with inplace`
# - [pandas.DataFrame.sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)

# %%
data.sort_values(['aperture','gpu_rank'],ascending=True,inplace=True) 
# Reassigning is not required becuase inplace will update the memory
data.head(10)
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 38         2         0        27   128.0            490                  1.7
# 40         0         1        38   143.0            275                  1.3
# 22         2         1        38   125.0            354                  1.3
# 23         3         1        43    97.0            345                  1.2
# 54         0         1        44   154.5            560                  1.7
# 55         1         1        44   171.8           1093                  1.4
# 28         0         1        44   160.0            617                  1.7
# 12         0         1        50   135.0            280                  1.4
# 20         0         1        55   152.0            450                  1.2
# 10         0         1        55   169.0            514                  1.3
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# ...

# %% [markdown]
# # `Dropping a values in Dataframe (row, columns)`

# %%
# columns drop
data.drop(["sim_type","stand_by_time"],inplace=True,axis=1) # since inplace is used it dropped a column from memory

# %%
data.head()
# Out:
#     aperture  gpu_rank  weight  processor_frequency  thickness  flash_type  \
# 38         0        27   128.0                  1.7        8.8           5
# 40         1        38   143.0                  1.3        8.5           5
# 22         1        38   125.0                  1.3        7.6           5
# 23         1        43    97.0                  1.2        5.1           5
# 54         1        44   154.5                  1.7        7.7           5
#
#     front_camera_resolution  auto_focus  screen_size  frames_per_second  ...  \
# 38                      5.0           3          5.0                 30  ...
# 40                      5.0           3          5.2                 30  ...
# 22                      5.0           3          5.0                 30  ...
# 23                      5.0           3          4.8                 30  ...
# 54                      8.0           3          5.5                 30  ...
#
# ...

# %%
# row drop
data.drop([38],inplace=True,axis=0)

# %%
data.head()
# Out:
#     aperture  gpu_rank  weight  processor_frequency  thickness  flash_type  \
# 40         1        38   143.0                  1.3        8.5           5
# 22         1        38   125.0                  1.3        7.6           5
# 23         1        43    97.0                  1.2        5.1           5
# 54         1        44   154.5                  1.7        7.7           5
# 55         1        44   171.8                  1.4        7.7           5
#
#     front_camera_resolution  auto_focus  screen_size  frames_per_second  ...  \
# 40                      5.0           3          5.2                 30  ...
# 22                      5.0           3          5.0                 30  ...
# 23                      5.0           3          4.8                 30  ...
# 54                      8.0           3          5.5                 30  ...
# 55                      1.1           3          6.0                 30  ...
#
# ...

# %% [markdown]
# # `Loading a new data`

# %%
data = pd.read_csv('Churn_Modelling.csv')

# %%
data.drop(['RowNumber','CustomerId'],axis=1,inplace=True)

# %%
data.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %% [markdown]
# # `Create a new columns and calculation of columns`
# - `Creating a new columns`
# - `data type conversion`
# - `Selection and replacing a content in a columns`

# %% [markdown]
# ## `creating a new columns`

# %%
data.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data["HasCrCard_formatted"] = data["HasCrCard"] # assigning to new columns

# %%
data.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'HasCrCard_formatted'],
#       dtype='object')

# %% [markdown]
# ## `datatype conversion`

# %%
data["HasCrCard_formatted"] = data["HasCrCard_formatted"].astype(str) # type conversion

# %%
data.dtypes
# Out:
# Surname                 object
# CreditScore              int64
# Geography               object
# Gender                  object
# Age                      int64
# Tenure                   int64
# Balance                float64
# NumOfProducts            int64
# HasCrCard                int64
# IsActiveMember           int64
# EstimatedSalary        float64
# Exited                   int64
# HasCrCard_formatted     object
# dtype: object

# %% [markdown]
# ## `Replace a value using selection`

# %%
data.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted
# 0                   1
# 1                   0
# 2                   1
# 3                   0
# 4                   1

# %%
import seaborn as sns
sns.distplot(data['EstimatedSalary'])
# Out:
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Density'>

# %%
data.loc[data["HasCrCard_formatted"]=="1","HasCrCard_formatted"] = "Yes"
data.loc[data["HasCrCard_formatted"]=="0","HasCrCard_formatted"] = "No"

# %%
data.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted
# 0                 Yes
# 1                  No
# 2                 Yes
# 3                  No
# 4                 Yes

# %% [markdown]
# ### `caculation on columns`

# %%
data["Saving_details"] = data["Balance"] - data["EstimatedSalary"]
data.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted  Saving_details
# 0                 Yes      -101348.88
# 1                  No       -28734.72
# ...

# %%
data["negative_balance"] = None

# %%
data.loc[data["Saving_details"]<0 , "negative_balance"] = "yes"
data.loc[data["Saving_details"]>0 , "negative_balance"] = "no"

# %%
data.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted  Saving_details negative_balance
# 0                 Yes      -101348.88              yes
# ...

# %% [markdown]
# # `Group By and aggregate`
# Pandas `dataframe.groupby()` function is used to split the data into groups based on some criteria. pandas objects can be split on any of their axes. The abstract definition of grouping is to provide a mapping of labels to group names.
#
# ![image.png](https://redash.io/assets/images/docs/gitbook/group-by-ex.png)

# %%
import warnings
warnings.filterwarnings('ignore')
data.mean()
# Out:
# CreditScore           650.528800
# Age                    38.921800
# Tenure                  5.012800
# Balance             76485.889288
# NumOfProducts           1.530200
# HasCrCard               0.705500
# IsActiveMember          0.515100
# EstimatedSalary    100090.239881
# Exited                  0.203700
# Saving_details     -23604.350593
# dtype: float64

# %%
data.groupby("Geography").mean()
# Out:
#            CreditScore        Age    Tenure        Balance  NumOfProducts  \
# Geography
# France      649.668329  38.511767  5.004587   62092.636516       1.530913
# Germany     651.453567  39.771622  5.009964  119730.116134       1.519729
# Spain       651.333872  38.890997  5.032297   61818.147763       1.539362
#
#            HasCrCard  IsActiveMember  EstimatedSalary    Exited  \
# Geography
# France      0.706621        0.516753     99899.180814  0.161548
# Germany     0.713830        0.497409    101113.435102  0.324432
# Spain       0.694792        0.529673     99440.572281  0.166734
#
#            Saving_details
# Geography
# France      -37806.544298
# Germany      18616.681032
# Spain       -37622.424518

# %%
data.groupby("Geography")["Age"].mean() # select a based on chaining
# Out:
# Geography
# France     38.511767
# Germany    39.771622
# Spain      38.890997
# Name: Age, dtype: float64

# %%
data.groupby("Geography")["Age"].max() # finding max
# Out:
# Geography
# France     92
# Germany    84
# Spain      88
# Name: Age, dtype: int64

# %%
data.groupby("Geography")[["Age","Tenure"]].min() # finding min
# Out:
#            Age  Tenure
# Geography
# France      18       0
# Germany     18       0
# Spain       18       0

# %%
data[["Geography","Age","Tenure"]].groupby("Geography").min() # efficeint way of doing
# Out:
#            Age  Tenure
# Geography
# France      18       0
# Germany     18       0
# Spain       18       0

# %%
data[["Geography","Age"]].groupby("Geography").agg(["mean","max","min","median"]) # Multiple agg functions
# Out:
#                  Age
#                 mean max min median
# Geography
# France     38.511767  92  18   37.0
# Germany    39.771622  84  18   38.0
# Spain      38.890997  88  18   37.0

# %%
data[["Geography","Age","Tenure"]].groupby("Geography").agg(["mean","max"]) 
# Multiple agg functions and Multiple columns
# Out:
#                  Age        Tenure
#                 mean max      mean max
# Geography
# France     38.511767  92  5.004587  10
# Germany    39.771622  84  5.009964  10
# Spain      38.890997  88  5.032297  10

# %%
data[["Geography","Age","Tenure"]].groupby("Geography").agg({"Age":"mean","Tenure":["min","max","count"]})
# We can pass the agg function with respect to columns name
# Out:
#                  Age Tenure
#                 mean    min max count
# Geography
# France     38.511767      0  10  5014
# Germany    39.771622      0  10  2509
# Spain      38.890997      0  10  2477

# %%
data.groupby(["Geography","Gender"])["Age"].agg(["mean","min","max"])
# Multiple groupy
# Out:
#                        mean  min  max
# Geography Gender
# France    Female  38.773994   18   85
#           Male    38.296404   18   92
# Germany   Female  40.154233   18   77
#           Male    39.424772   18   84
# Spain     Female  39.199265   19   79
#           Male    38.649135   18   88

# %%
data.groupby(["Geography","Gender"])["Age"].agg(age_mean="mean",age_min="min",age_max="max")
# giving custom column names to agg function
# Out:
#                    age_mean  age_min  age_max
# Geography Gender
# France    Female  38.773994       18       85
#           Male    38.296404       18       92
# Germany   Female  40.154233       18       77
#           Male    39.424772       18       84
# Spain     Female  39.199265       19       79
#           Male    38.649135       18       88

# %% [markdown]
# # `Renaming a columns`

# %%
data.head()
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted  Saving_details negative_balance
# 0                 Yes      -101348.88              yes
# ...

# %%
data.rename(columns={"Surname":"name"},inplace=True)

# %%
data.head()
# Out:
#        name  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted  Saving_details negative_balance
# 0                 Yes      -101348.88              yes
# ...

# %% [markdown]
# # `set_index and reset_index => Indexing and multiple indexing`

# %%
data.set_index("Geography",inplace=True) # => single indexing creation

# %%
data
# Out:
#                 name  CreditScore  Gender  Age  Tenure    Balance  \
# Geography
# France      Hargrave          619  Female   42       2       0.00
# Spain           Hill          608  Female   41       1   83807.86
# France          Onio          502  Female   42       8  159660.80
# France          Boni          699  Female   39       1       0.00
# Spain       Mitchell          850  Female   43       2  125510.82
# ...              ...          ...     ...  ...     ...        ...
# France      Obijiaku          771    Male   39       5       0.00
# France     Johnstone          516    Male   35      10   57369.61
# France           Liu          709  Female   36       7       0.00
# Germany    Sabbatini          772    Male   42       3   75075.31
# France        Walker          792  Female   28       4  130142.79
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# Geography
# ...

# %%
data.loc["Germany"]
# Out:
#                      name  CreditScore  Gender  Age  Tenure    Balance  \
# Geography
# Germany            Obinna          376  Female   29       4  115046.74
# Germany           Goforth          616    Male   45       3  143129.41
# Germany             Romeo          653    Male   58       1  132602.88
# Germany             Young          756    Male   36       2  136815.64
# Germany        McWilliams          574  Female   43       3  141349.43
# ...                   ...          ...     ...  ...     ...        ...
# Germany           Griffin          655  Female   46       7  137145.12
# Germany    Echezonachukwu          602    Male   35       7   90602.42
# Germany          Bartlett          673    Male   47       1  183579.54
# Germany        Nkemakonam          714    Male   33       3   35016.60
# Germany         Sabbatini          772    Male   42       3   75075.31
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# Geography
# ...

# %%
data.reset_index(inplace=True) # Reset indexing

# %%
data
# Out:
#      Geography       name  CreditScore  Gender  Age  Tenure    Balance  \
# 0       France   Hargrave          619  Female   42       2       0.00
# 1        Spain       Hill          608  Female   41       1   83807.86
# 2       France       Onio          502  Female   42       8  159660.80
# 3       France       Boni          699  Female   39       1       0.00
# 4        Spain   Mitchell          850  Female   43       2  125510.82
# ...        ...        ...          ...     ...  ...     ...        ...
# 9995    France   Obijiaku          771    Male   39       5       0.00
# 9996    France  Johnstone          516    Male   35      10   57369.61
# 9997    France        Liu          709  Female   36       7       0.00
# 9998   Germany  Sabbatini          772    Male   42       3   75075.31
# 9999    France     Walker          792  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
data.set_index(["Geography","Gender"],inplace=True) # => Multiple indexing creation

# %%
data.sample(10)
# Out:
#                        name  CreditScore  Age  Tenure    Balance  \
# Geography Gender
# Germany   Female   Zetticci          791   35       7   52436.20
#           Male    Sanderson          553   41       9  110112.54
#           Female       Rohu          678   25      10   76968.12
# France    Female  Ogochukwu          670   31       2   57530.06
#           Male        Scott          695   29       5       0.00
#           Female     Hunter          850   35       5       0.00
#           Male      Aksenov          714   37       9  148466.93
# Germany   Female     Forbes          689   40       4   78119.59
# Spain     Male        Greco          730   62       2       0.00
# Germany   Male    Larionova          758   41      10   79857.64
#
#                   NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Geography Gender
# Germany   Female              1          1               0        161051.75
# ...

# %%
data.loc[[("Germany","Female")]]
# Out:
#                         name  CreditScore  Age  Tenure    Balance  \
# Geography Gender
# Germany   Female      Obinna          376   29       4  115046.74
#           Female  McWilliams          574   43       3  141349.43
#           Female       Tyler          776   32       4  109421.13
#           Female      Martin          829   27       9  112045.67
#           Female     Okagbue          637   39       9  137843.80
# ...                      ...          ...  ...     ...        ...
#           Female     Salinas          625   39      10  129845.26
#           Female    Lucciano          795   33       9  104552.72
#           Female        Shao          627   33       4   83199.05
#           Female    McGregor          512   40       8  153537.57
#           Female     Griffin          655   46       7  137145.12
#
#                   NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Geography Gender
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      Geography  Gender       name  CreditScore  Age  Tenure    Balance  \
# 0       France  Female   Hargrave          619   42       2       0.00
# 1        Spain  Female       Hill          608   41       1   83807.86
# 2       France  Female       Onio          502   42       8  159660.80
# 3       France  Female       Boni          699   39       1       0.00
# 4        Spain  Female   Mitchell          850   43       2  125510.82
# ...        ...     ...        ...          ...  ...     ...        ...
# 9995    France    Male   Obijiaku          771   39       5       0.00
# 9996    France    Male  Johnstone          516   35      10   57369.61
# 9997    France  Female        Liu          709   36       7       0.00
# 9998   Germany    Male  Sabbatini          772   42       3   75075.31
# 9999    France  Female     Walker          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
data.reset_index() # will insert a index into the dataframe
# Out:
#       index Geography  Gender       name  CreditScore  Age  Tenure    Balance  \
# 0         0    France  Female   Hargrave          619   42       2       0.00
# 1         1     Spain  Female       Hill          608   41       1   83807.86
# 2         2    France  Female       Onio          502   42       8  159660.80
# 3         3    France  Female       Boni          699   39       1       0.00
# 4         4     Spain  Female   Mitchell          850   43       2  125510.82
# ...     ...       ...     ...        ...          ...  ...     ...        ...
# 9995   9995    France    Male   Obijiaku          771   39       5       0.00
# 9996   9996    France    Male  Johnstone          516   35      10   57369.61
# 9997   9997    France  Female        Liu          709   36       7       0.00
# 9998   9998   Germany    Male  Sabbatini          772   42       3   75075.31
# 9999   9999    France  Female     Walker          792   28       4  130142.79
#
# ...

# %%
data.reset_index(drop=True) # will insert a index into the dataframe; we can drop unnecessary columns
# Out:
#      Geography  Gender       name  CreditScore  Age  Tenure    Balance  \
# 0       France  Female   Hargrave          619   42       2       0.00
# 1        Spain  Female       Hill          608   41       1   83807.86
# 2       France  Female       Onio          502   42       8  159660.80
# 3       France  Female       Boni          699   39       1       0.00
# 4        Spain  Female   Mitchell          850   43       2  125510.82
# ...        ...     ...        ...          ...  ...     ...        ...
# 9995    France    Male   Obijiaku          771   39       5       0.00
# 9996    France    Male  Johnstone          516   35      10   57369.61
# 9997    France  Female        Liu          709   36       7       0.00
# 9998   Germany    Male  Sabbatini          772   42       3   75075.31
# 9999    France  Female     Walker          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %% [markdown]
# # `Pivot table`
#
#
# A pivot table is a data summarization tool that is used in the context of data processing. **Pivot tables are used to summarize, sort, reorganize, group, count, total or average data stored in a database**. It allows its users to transform columns into rows and rows into columns. It allows grouping by any data field. Pivot tables are the perfect solution when you need to summarize and analyze large amounts of data.

# %%
data.groupby("Geography")["CreditScore"].agg(["min","max"])
# Out:
#            min  max
# Geography
# France     350  850
# Germany    350  850
# Spain      350  850

# %%
data.pivot_table(index="Geography",values="CreditScore",aggfunc=["min","max"])
# Out:
#                   min         max
#           CreditScore CreditScore
# Geography
# France            350         850
# Germany           350         850
# Spain             350         850

# %%
data.groupby(["Geography","Gender"])["Balance"].mean()
# Out:
# Geography  Gender
# France     Female     60322.670159
#            Male       63546.284875
# Germany    Female    119145.966471
#            Male      120259.668222
# Spain      Female     59862.092534
#            Male       63352.833746
# Name: Balance, dtype: float64

# %%
data.pivot_table(index=["Geography","Gender"], values=["Balance"],aggfunc="mean")
# Out:
#                         Balance
# Geography Gender
# France    Female   60322.670159
#           Male     63546.284875
# Germany   Female  119145.966471
#           Male    120259.668222
# Spain     Female   59862.092534
#           Male     63352.833746

# %%
data.pivot_table(index=["Geography"], columns="Gender", values=["Balance"],aggfunc="mean")
# Out:
#                  Balance
# Gender            Female           Male
# Geography
# France      60322.670159   63546.284875
# Germany    119145.966471  120259.668222
# Spain       59862.092534   63352.833746

# %% [markdown]
# # `cross tab`

# %%
pd.crosstab(data['Geography'],data['Gender'])
# Out:
# Gender     Female  Male
# Geography
# France       2261  2753
# Germany      1193  1316
# Spain        1089  1388

# %%
data.groupby(["Geography","Gender"])["name"].count()
# Out:
# Geography  Gender
# France     Female    2261
#            Male      2753
# Germany    Female    1193
#            Male      1316
# Spain      Female    1089
#            Male      1388
# Name: name, dtype: int64

# %%
data.pivot_table(index=["Geography"], columns="Gender", values=["Gender"],aggfunc="count")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6632/2262130245.py in <module>
# ----> 1 data.pivot_table(index=["Geography"], columns="Gender", values=["Gender"],aggfunc="count")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    7949         from pandas.core.reshape.pivot import pivot_table
#    7950
# -> 7951         return pivot_table(
#    7952             self,
#    7953             values=values,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ---> 95     table = __internal_pivot_table(
#      96         data,
# ...

# %% [markdown]
# ## `two way frequency table`

# %%
pd.crosstab(data["Geography"],data["Gender"])
# Out:
# Gender     Female  Male
# Geography
# France       2261  2753
# Germany      1193  1316
# Spain        1089  1388

# %% [markdown]
# # `Stacking and Unstacking`
# - Stacking can be done using mulitindex without duplicates
# - Groupby

# %%
data.groupby(['Geography',"Gender"])["CreditScore"].mean() # stacked output
# Out:
# Geography  Gender
# France     Female    649.185759
#            Male      650.064657
# Germany    Female    653.093881
#            Male      649.966565
# Spain      Female    651.769513
#            Male      650.992075
# Name: CreditScore, dtype: float64

# %%
data.groupby(['Geography',"Gender"])["CreditScore"].mean().unstack(level=0)
# Out:
# Geography      France     Germany       Spain
# Gender
# Female     649.185759  653.093881  651.769513
# Male       650.064657  649.966565  650.992075

# %%
data.groupby(['Geography',"Gender"])["CreditScore"].mean().unstack(level=1)
# Out:
# Gender         Female        Male
# Geography
# France     649.185759  650.064657
# Germany    653.093881  649.966565
# Spain      651.769513  650.992075

# %% [markdown]
# # `Concatenate`

# %%
data1 = data.copy()
data2 = data.copy()

# %%
data1
# Out:
#      Geography  Gender       name  CreditScore  Age  Tenure    Balance  \
# 0       France  Female   Hargrave          619   42       2       0.00
# 1        Spain  Female       Hill          608   41       1   83807.86
# 2       France  Female       Onio          502   42       8  159660.80
# 3       France  Female       Boni          699   39       1       0.00
# 4        Spain  Female   Mitchell          850   43       2  125510.82
# ...        ...     ...        ...          ...  ...     ...        ...
# 9995    France    Male   Obijiaku          771   39       5       0.00
# 9996    France    Male  Johnstone          516   35      10   57369.61
# 9997    France  Female        Liu          709   36       7       0.00
# 9998   Germany    Male  Sabbatini          772   42       3   75075.31
# 9999    France  Female     Walker          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %% [markdown]
# ## `vstack or hstack`

# %%
data_c = pd.concat([data1,data2],axis=0) # control using axis for vstack or hstack

# %%
data_c
# Out:
#      Geography  Gender       name  CreditScore  Age  Tenure    Balance  \
# 0       France  Female   Hargrave          619   42       2       0.00
# 1        Spain  Female       Hill          608   41       1   83807.86
# 2       France  Female       Onio          502   42       8  159660.80
# 3       France  Female       Boni          699   39       1       0.00
# 4        Spain  Female   Mitchell          850   43       2  125510.82
# ...        ...     ...        ...          ...  ...     ...        ...
# 9995    France    Male   Obijiaku          771   39       5       0.00
# 9996    France    Male  Johnstone          516   35      10   57369.61
# 9997    France  Female        Liu          709   36       7       0.00
# 9998   Germany    Male  Sabbatini          772   42       3   75075.31
# 9999    France  Female     Walker          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
data_c2 = pd.concat([data1,data2],axis=1) # control using axis for vstack or hstack

# %%
data_c2
# Out:
#      Geography  Gender       name  CreditScore  Age  Tenure    Balance  \
# 0       France  Female   Hargrave          619   42       2       0.00
# 1        Spain  Female       Hill          608   41       1   83807.86
# 2       France  Female       Onio          502   42       8  159660.80
# 3       France  Female       Boni          699   39       1       0.00
# 4        Spain  Female   Mitchell          850   43       2  125510.82
# ...        ...     ...        ...          ...  ...     ...        ...
# 9995    France    Male   Obijiaku          771   39       5       0.00
# 9996    France    Male  Johnstone          516   35      10   57369.61
# 9997    France  Female        Liu          709   36       7       0.00
# 9998   Germany    Male  Sabbatini          772   42       3   75075.31
# 9999    France  Female     Walker          792   28       4  130142.79
#
#      NumOfProducts  HasCrCard IsActiveMember  ...  Tenure    Balance  \
# ...

# %% [markdown]
# # `Concatenate, Merge, Join`
#
# ### [merge, join and concatenate](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
#
# **These functions are used to combine multiple dataframes**. It is important to understand their usage.
#
# Here's a quick summary:
# - **merge()** for **combining data on common columns or indices**
# - **.join()** for **combining data on a key column or an index**
# - **concat()** for **combining DataFrames across rows or columns**
#
#
# ## `What is a Join Operation?`
# Join is a common database operation which combines data from two files, data sources, tables, views, or query outputs based on a given condition.
# ![Join Operations](https://www1.udel.edu/evelyn/SQL-Class2/joins.jpg)
#
#
#
# ## `Merge`
#
#
# ## `Concatenate`
# Concatenation is a process of joining of the object along an axis, with set logic applied to other axes, if any (because a series doesn’t have any other axes). These are the main parameters involved in pandas concatenation- object, axis, handling of other axes, and keys.

# %% [markdown]
# ## `concat()`

# %%
df1 = pd.DataFrame([{"City":"Mysore", "state":"Karnataka"},{"City":"Hyderabad", "state":"Telangana"},{"City":"Bangalore","state":"Karnataka"},{"City":"Vizag", "state":"Andhra"}])
df1
# Out:
#         City      state
# 0     Mysore  Karnataka
# 1  Hyderabad  Telangana
# 2  Bangalore  Karnataka
# 3      Vizag     Andhra

# %%
df2 = pd.DataFrame([{"City":"Chandigarh","state":"Punjab"},{"City":"Tirupati","state":"Andhra"}])
df2
# Out:
#          City   state
# 0  Chandigarh  Punjab
# 1    Tirupati  Andhra

# %%
pd.concat([df1,df2])
# Out:
#          City      state
# 0      Mysore  Karnataka
# 1   Hyderabad  Telangana
# 2   Bangalore  Karnataka
# 3       Vizag     Andhra
# 0  Chandigarh     Punjab
# 1    Tirupati     Andhra

# %% [markdown]
# ## `Join`

# %%
df1 = pd.DataFrame([{"City":"Mysore", "state":"Karnataka"},{"City":"Hyderabad", "state":"Telangana"},{"City":"Bangalore","state":"Karnataka"},{"City":"Vizag", "state":"Andhra"}])
df1
# Out:
#         City      state
# 0     Mysore  Karnataka
# 1  Hyderabad  Telangana
# 2  Bangalore  Karnataka
# 3      Vizag     Andhra

# %%
df2 = pd.DataFrame([{"City":"Mysore","rev":10000},{"City":"Hyderabad","rev":5000},{"City":"Sec - Hyderabad","rev":5000}])
df2
# Out:
#               City    rev
# 0           Mysore  10000
# 1        Hyderabad   5000
# 2  Sec - Hyderabad   5000

# %%
pd.merge(df1, df2 , how='inner', on='City') ## ineer join
# Out:
#         City      state    rev
# 0     Mysore  Karnataka  10000
# 1  Hyderabad  Telangana   5000

# %%
pd.merge(df1, df2 , how='left', on='City') ## left join
# Out:
#         City      state      rev
# 0     Mysore  Karnataka  10000.0
# 1  Hyderabad  Telangana   5000.0
# 2  Bangalore  Karnataka      NaN
# 3      Vizag     Andhra      NaN

# %%
pd.merge(df1, df2 , how='right', on='City') ## right join
# Out:
#               City      state    rev
# 0           Mysore  Karnataka  10000
# 1        Hyderabad  Telangana   5000
# 2  Sec - Hyderabad        NaN   5000

# %%
data_temp = pd.merge(df1, df2 , how='outer', on='City') ## full outer join
data_temp
# Out:
#               City      state      rev
# 0           Mysore  Karnataka  10000.0
# 1        Hyderabad  Telangana   5000.0
# 2        Bangalore  Karnataka      NaN
# 3            Vizag     Andhra      NaN
# 4  Sec - Hyderabad        NaN   5000.0

# %% [markdown]
# ## `merge()`
# ### `first example`

# %%
left = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
result = pd.merge(left, right, on="key")
result
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# ### `second example`

# %%
left = pd.DataFrame(
    {
        "key1": ["K0", "K0", "K1", "K2"],
        "key2": ["K0", "K1", "K0", "K1"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right = pd.DataFrame(
    {
        "key1": ["K0", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K0", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
result = pd.merge(left, right, on=["key1", "key2"])
result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# # `handling a str columns`

# %%
data["name"]
# Out:
# 0        Hargrave
# 1            Hill
# 2            Onio
# 3            Boni
# 4        Mitchell
#           ...
# 9995     Obijiaku
# 9996    Johnstone
# 9997          Liu
# 9998    Sabbatini
# 9999       Walker
# Name: name, Length: 10000, dtype: object

# %%
data["name"].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6632/3671705862.py in <module>
# ----> 1 data["name"].lower()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
data["name"].str.lower()
# Out:
# 0        hargrave
# 1            hill
# 2            onio
# 3            boni
# 4        mitchell
#           ...
# 9995     obijiaku
# 9996    johnstone
# 9997          liu
# 9998    sabbatini
# 9999       walker
# Name: name, Length: 10000, dtype: object

# %%
data["name"].str.upper()
# Out:
# 0        HARGRAVE
# 1            HILL
# 2            ONIO
# 3            BONI
# 4        MITCHELL
#           ...
# 9995     OBIJIAKU
# 9996    JOHNSTONE
# 9997          LIU
# 9998    SABBATINI
# 9999       WALKER
# Name: name, Length: 10000, dtype: object

# %%
data["name"].str.split(" ")
# Out:
# 0        [Hargrave]
# 1            [Hill]
# 2            [Onio]
# 3            [Boni]
# 4        [Mitchell]
#            ...
# 9995     [Obijiaku]
# 9996    [Johnstone]
# 9997          [Liu]
# 9998    [Sabbatini]
# 9999       [Walker]
# Name: name, Length: 10000, dtype: object

# %% [markdown]
# # `Iteration and adding new columns`

# %%
data["balance_cal"] = data["EstimatedSalary"] - data["Balance"]

# %%
data["balance_cal"]
# Out:
# 0       101348.88
# 1        28734.72
# 2       -45729.23
# 3        93826.63
# 4       -46426.72
#           ...
# 9995     96270.64
# 9996     44330.16
# 9997     42085.58
# 9998     17813.21
# 9999    -91952.01
# Name: balance_cal, Length: 10000, dtype: float64

# %%
data.head()
# Out:
#   Geography  Gender      name  CreditScore  Age  Tenure    Balance  \
# 0    France  Female  Hargrave          619   42       2       0.00
# 1     Spain  Female      Hill          608   41       1   83807.86
# 2    France  Female      Onio          502   42       8  159660.80
# 3    France  Female      Boni          699   39       1       0.00
# 4     Spain  Female  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted  Saving_details negative_balance  balance_cal
# 0                 Yes      -101348.88              yes    101348.88
# ...

# %%
data["credit_Cat"] = None
for index, row in data.iterrows():
    if row["CreditScore"] > 750:
        data.loc[index,"credit_Cat"] = "Good"
    else:
        data.loc[index,"credit_Cat"] = "Bad"

# %%
data["credit_Cat"].head()
# Out:
# 0     Bad
# 1     Bad
# 2     Bad
# 3     Bad
# 4    Good
# Name: credit_Cat, dtype: object

# %%
data["credit_cat"] = data["CreditScore"].apply(lambda x:"good" if x>750 else "bad")
data.head()
# Out:
#   Geography  Gender      name  CreditScore  Age  Tenure    Balance  \
# 0    France  Female  Hargrave          619   42       2       0.00
# 1     Spain  Female      Hill          608   41       1   83807.86
# 2    France  Female      Onio          502   42       8  159660.80
# 3    France  Female      Boni          699   39       1       0.00
# 4     Spain  Female  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#   HasCrCard_formatted  Saving_details negative_balance  balance_cal  \
# 0                 Yes      -101348.88              yes    101348.88
# ...

# %%
data.groupby(['Geography',"Gender"])["CreditScore"].mean()
# Out:
# Geography  Gender
# France     Female    649.185759
#            Male      650.064657
# Germany    Female    653.093881
#            Male      649.966565
# Spain      Female    651.769513
#            Male      650.992075
# Name: CreditScore, dtype: float64

# %%
data[["Age","CreditScore"]].apply("mean",axis=0) # column
# Out:
# Age             38.9218
# CreditScore    650.5288
# dtype: float64

# %%
data[["Age","CreditScore"]].apply("mean",axis=1) # rowmean
# Out:
# 0       330.5
# 1       324.5
# 2       272.0
# 3       369.0
# 4       446.5
#         ...
# 9995    405.0
# 9996    275.5
# 9997    372.5
# 9998    407.0
# 9999    410.0
# Length: 10000, dtype: float64

# %% [markdown]
# # `Handling missing`
#
# ## `Treating Missing Values`
# There are two ways to treat missing values:
#
# - Delete: Delete the missing values
# - Impute:
#   - **Imputing by a simple statistic: Replace the missing values by another value, commonly the mean, median, mode etc**.
#   - **Predictive techniques: Use statistical models such as k-NN, SVM etc. to predict and impute missing values.**
#
# ### `Note`:
# When imputing the missing values with the descriptive statistics, we are making an assumption as we don't know the true values which are missing. Hence, missing values imputation should be performed only when we are confident about our assumptions. On the other hand, removing missing data is often considered safer as we aren't making any assumptions and are not adding any data to the dataset
#
# ### `General rules for missing value handling`
# - If less than 5% of the data in a column is missing, we can safely remove the rows which have the missing values as we'll still be left with atleast 95% of rows
# - If atleast 40% of the data goes missing in a column, it's better we remove the entire column as the data we know is less than the data we don't know
# - For rest of the cases. depending on how the data is distributed, we can impute the values
#
# Note: When handling missing values, we have to handle each column separately

# %%
data_temp2 = data_temp.copy()

# %%
data_temp2
# Out:
#               City      state      rev
# 0           Mysore  Karnataka  10000.0
# 1        Hyderabad  Telangana   5000.0
# 2        Bangalore  Karnataka      NaN
# 3            Vizag     Andhra      NaN
# 4  Sec - Hyderabad        NaN   5000.0

# %%
data_temp2["state"].fillna("Andhra",inplace=True)

# %%
data_temp2
# Out:
#               City      state      rev
# 0           Mysore  Karnataka  10000.0
# 1        Hyderabad  Telangana   5000.0
# 2        Bangalore  Karnataka      NaN
# 3            Vizag     Andhra      NaN
# 4  Sec - Hyderabad     Andhra   5000.0

# %%
mean_of_rev = data_temp["rev"].mean(skipna=True)
mean_of_rev
# Out:
# 6666.666666666667

# %%
data_temp["rev"].fillna(mean_of_rev,inplace=True)

# %%
data_temp
# Out:
#               City      state           rev
# 0           Mysore  Karnataka  10000.000000
# 1        Hyderabad  Telangana   5000.000000
# 2        Bangalore  Karnataka   6666.666667
# 3            Vizag     Andhra   6666.666667
# 4  Sec - Hyderabad        NaN   5000.000000

# %%
data_temp2
# Out:
#               City      state      rev
# 0           Mysore  Karnataka  10000.0
# 1        Hyderabad  Telangana   5000.0
# 2        Bangalore  Karnataka      NaN
# 3            Vizag     Andhra      NaN
# 4  Sec - Hyderabad     Andhra   5000.0

# %%
# drop na 
data_temp2.dropna() # get only not null values
# Out:
#               City      state      rev
# 0           Mysore  Karnataka  10000.0
# 1        Hyderabad  Telangana   5000.0
# 4  Sec - Hyderabad     Andhra   5000.0

# %% [markdown]
# # `Other function in Pandas and Pandas plot`

# %% [markdown]
# ### `important function in pandas`

# %%
data["Balance"].describe()
# Out:
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: Balance, dtype: float64

# %%
data["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data["Geography"].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
data["Geography"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data["Geography"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Geography'>

# %%
data[["Balance","CreditScore"]].plot.scatter("Balance","CreditScore")
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='CreditScore'>

# %%
data[["EstimatedSalary","Balance"]].plot.line("EstimatedSalary","Balance")
# Out:
# <AxesSubplot:xlabel='EstimatedSalary'>

# %% [markdown]
# # `END -------------------------------------------------------------`
